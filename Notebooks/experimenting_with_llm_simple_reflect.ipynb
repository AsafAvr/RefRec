# %% [markdown]
# # Experimenting with Self-Reflection Mechanism & Recommendation Systems

# %% [markdown]
# ## Git Dependencies

# %%
# !git clone github.com/AsafAvr/RefRec.git
# Out:
# Cloning into 'RefRec'...
# remote: Enumerating objects: 96, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 96 (delta 12), reused 26 (delta 3), pack-reused 52
# Receiving objects: 100% (96/96), 49.63 MiB | 11.40 MiB/s, done.
# Resolving deltas: 100% (16/16), done.
# Updating files: 100% (52/52), done.

# %%
# %cd /content/RefRec
# !pip install -q -r requirements.txt

# %% [markdown]
# # Outline
# - Load validation dataset - Movielens-1M
# - Load recommendation model that was finetuned on specific embedding spce (TBC)
# - Create a self-reflection mechanism on the validation dataset
#   - Predict the next sequence for a specific user by prompting the llm with the data about the user
#     - Generate prompt to encode specific features
#   - reflect on the prediction vs the ground truth
#   - suggest a better feature and reflect on why the mistake happened
#   - continue to the next sequence

# %% [markdown]
# ## Imports

# %%
device = 'cuda'

# %%
from pathlib import Path
cur_path = Path.cwd()
cur_path
# Out:
# PosixPath('/content/RefRec')

# %%
klg_folder = Path.cwd().joinpath('knowledge_encoding')
rs_folder = Path.cwd().joinpath('RS')
ml1m_folder = Path.cwd().joinpath('data').joinpath('ml-1m')
preprocess_folder = Path.cwd().joinpath('preprocess')

# %%
import sys
sys.path.append(klg_folder.as_posix())
sys.path.append(rs_folder.as_posix())
sys.path.append(preprocess_folder.as_posix())
from lm_encoding import get_text_data_loader
from pre_utils import GENDER_MAPPING, AGE_MAPPING, OCCUPATION_MAPPING

# %%
import numpy as np
import pandas as pd
import torch
import torch.utils.data as Data
import re

from dataset import AmzDataset
from main_ctr import eval
from utils import load_json
from sklearn.metrics import log_loss, roc_auc_score

# %%
class ShortDataLoader:
    def __init__(self, dataloader, num_batches):
        self.dataloader = dataloader
        self.num_batches = num_batches

    def __iter__(self):
        count = 0
        for batch in self.dataloader:
            if count >= self.num_batches:
                break
            yield batch
            count += 1

    def __len__(self):
        return min(len(self.dataloader), self.num_batches)

from torch.utils.data import Dataset
class DictDataset(Dataset):
    def __init__(self, data_list):
        self.data_list = data_list

    def __getitem__(self, index):
        return self.data_list[index]

    def __len__(self):
        return len(self.data_list)

# %% [markdown]
# ## Loading Train & Test datasets

# %%
model_path = rs_folder.joinpath('model').joinpath('ml-1m').joinpath('ctr').joinpath('DIN').joinpath('DIN.pt').as_posix()
inference_model = torch.load(model_path,map_location=torch.device(device))
train_set = AmzDataset(ml1m_folder.joinpath('proc_data').as_posix(), 'train', 'ctr', 5, True, 'bert_avg') #test
train_loader = Data.DataLoader(dataset=train_set, batch_size=2048, shuffle=False)

# %%
len(train_set)
# Out:
# 751436

# %%
test_set = AmzDataset(ml1m_folder.joinpath('proc_data').as_posix(), 'test', 'ctr', 5, True, 'bert_avg') #test
len(test_set)
# Out:
# 92024

# %%
user_vec_dict = load_json(ml1m_folder.joinpath('proc_data').joinpath('bert_avg_augment.hist'))
list(user_vec_dict.keys())[:10]
# Out:
# ['2179', '3813', '2108', '778', '4232', '2903', '2449', '5286', '4235', '3020']

# %%
item_vec_dict = load_json(ml1m_folder.joinpath('proc_data').joinpath('bert_avg_augment.item'))
list(item_vec_dict.keys())[:10]
# Out:
# ['1', '2', '4', '3', '5', '6', '7', '9', '8', '11']

# %% [markdown]
# ## Extracting metadata for LLM

# %%
hist_loader, hist_idxes, item_loader, item_idxes = get_text_data_loader(ml1m_folder.joinpath('knowledge').as_posix(), 1)

# %%
def get_user_hist(user_vec,hist_idxes):
    user_vec = user_vec.tolist()
    for key, v in user_vec_dict.items():
        if v == user_vec:
            user_index = hist_idxes.index(key)
            return key,user_index,hist_loader.dataset[user_index]
    return None

def get_item_desc(item_vec, item_idxes):
    item_vec = item_vec.tolist()
    for key,v in item_vec_dict.items():
        if v == item_vec:
            item_index = item_idxes.index(key)
            return key,item_index, item_loader.dataset[item_index]
    return None

# %%
user_prompt_dict = load_json(ml1m_folder.joinpath('proc_data').joinpath('prompt.hist').as_posix())
item_prompt_dict = load_json(ml1m_folder.joinpath('proc_data').joinpath('prompt.item').as_posix())
datamap = load_json(ml1m_folder.joinpath('proc_data').joinpath('datamaps.json').as_posix())
sequence_data = load_json(ml1m_folder.joinpath('proc_data').joinpath('sequential_data.json').as_posix())
train_test_split = load_json(ml1m_folder.joinpath('proc_data').joinpath('train_test_split.json').as_posix())
id2user = datamap['id2user']
id2item = datamap['id2item']

# %%
data_list = []
for i in range(10000):
    data = train_set[i]
    user_key, user_idx, user_hist = get_user_hist(data['hist_aug_vec'], hist_idxes)
    item_key, item_idx, item_desc = get_item_desc(data['item_aug_vec'], item_idxes)
    data_list.append({'test_index': i, 'user_idx': user_idx, 'user_key': user_key, 'user_hist': user_hist, 'item_idx': item_idx,'item_key': item_key, 'item_desc': item_desc })
df_train = pd.DataFrame(data_list)

# %%
data_list = []
for i in range(10000):
    data = test_set[i]
    user_key, user_idx, user_hist = get_user_hist(data['hist_aug_vec'], hist_idxes)
    item_key, item_idx, item_desc = get_item_desc(data['item_aug_vec'], item_idxes)
    data_list.append({'test_index': i, 'user_idx': user_idx, 'user_key': user_key, 'user_hist': user_hist, 'item_idx': item_idx,'item_key': item_key, 'item_desc': item_desc })
df_test = pd.DataFrame(data_list)

# %%
data.keys()
for key in data.keys():
  if key != 'hist_aug_vec' and key != 'item_aug_vec':
    print(key,data[key])
# Out:
# iid tensor(297)
# aid tensor([4])
# lb tensor(1)
# hist_iid_seq tensor([ 292,  980,  427, 1277,  107])
# hist_aid_seq tensor([[4],
#         [4],
#         [3],
#         [5],
#         [3]])
# hist_rate_seq tensor([2, 5, 4, 4, 5])
# hist_seq_len tensor(5)

# %%
df_train.loc[0]
# Out:
# test_index                                                    0
# user_idx                                                   4130
# user_key                                                   2336
# user_hist     Given a male user who is aged 35-44 and a trad...
# item_idx                                                   3440
# item_key                                                   3508
# item_desc     The Outlaw Josey Wales is a 1976 American West...
# Name: 0, dtype: object

# %%
id2user[df_train['user_key'][0]]
# Out:
# '4593'

# %%
user_prompt_dict[id2user[df_train['user_key'][0]]]
# Out:
# 'Given a male user who is aged 35-44 and a tradesman/craftsman, this user\'s movie viewing history over time is listed below. "Honey, I Shrunk the Kids (1989)", 1 stars; "The Parent Trap (1998)", 3 stars; "Home Alone (1990)", 3 stars; "Ghost (1990)", 3 stars; "Aladdin (1992)", 4 stars; "Waiting to Exhale (1995)", 2 stars; "Father of the Bride Part II (1995)", 3 stars; "Ghosts of Mississippi (1996)", 3 stars; "The Insider (1999)", 3 stars; "Roger & Me (1989)", 4 stars; "The Purple Rose of Cairo (1985)", 2 stars; "Michael (1996)", 2 stars; "Doctor Zhivago (1965)", 5 stars; "Fanny and Alexander (1982)", 4 stars; "The Trip to Bountiful (1985)", 4 stars; "Dances with Wolves (1990)", 2 stars; "Batman (1989)", 2 stars; "The Silence of the Lambs (1991)", 4 stars; "Pretty Woman (1990)", 3 stars; "Tender Mercies (1983)", 4 stars; "And the Band Played On (1993)", 4 stars; "Evita (1996)", 3 stars; "Blue Velvet (1986)", 3 stars; "Little Big Man (1970)", 3 stars; "Kolya (1996)", 5 stars; "Dogma (1999)", 3 stars; "The Messenger: The Story of Joan of Arc (1999)", 3 stars; "Cocoon (1985)", 3 stars; "Women on the Verge of a Nervous Breakdown (1988)", 3 stars; "You\'ve Got Mail (1998)", 3 stars; Analyze user\'s preferences on movies (consider factors like genre, director/actors, time period/country, character, plot/theme, mood/tone, critical acclaim/award, production quality, and soundtrack). Provide clear explanations based on relevant details from the user\'s movie viewing history and other pertinent factors.'

# %%
item_prompt_dict[df_train['item_key'][0]]
# Out:
# 'Introduce movie The Outlaw Josey Wales (1976) and describe its attributes (including but not limited to genre, director/cast, country, character, plot/theme, mood/tone, critical acclaim/award, production quality, and soundtrack).'

# %%
len(df_train)
# Out:
# 10000

# %%
len(df_test)
# Out:
# 92024

# %%
question = 'Analyze user\'s preferences on movies (consider factors like genre, director/actors, time ' \
                    'period/country, character, plot/theme, mood/tone, critical acclaim/award, production quality, ' \
                    'and soundtrack). Provide clear explanations based on relevant details from the user\'s movie ' \
                    'viewing history and other pertinent factors.'

# %%
lm_hist_idx = train_test_split['lm_hist_idx']
itemid2title = datamap['itemid2title']
user2attribute = datamap['user2attribute']

for uid, item_rating in sequence_data.items():
    user = id2user[uid]
    item_seq, rating_seq = item_rating
    cur_idx = lm_hist_idx[uid]
    hist_item_seq = item_seq[:cur_idx]
    hist_rating_seq = rating_seq[:cur_idx]
    history_texts = []
    movie_history = []
    for iid, rating in zip(hist_item_seq, hist_rating_seq):
        tmp = '"{}", {} stars; '.format(itemid2title[str(iid)], int(rating))
        movie_history.append({'title': itemid2title[str(iid)], 'rating': rating})
        history_texts.append(tmp)
    break
# uid, item_seq, rating_seq
# history_texts
len(movie_history)
# Out:
# 30

# %%
gender, age, occupation = user2attribute[uid]
user_text = 'Given a {} user who is aged {} and {}, this user\'s movie viewing history over time' \
            ' is listed below. '.format(GENDER_MAPPING[gender], AGE_MAPPING[age],
                                        OCCUPATION_MAPPING[occupation])
user_text
# Out:
# "Given a female user who is aged under 18 and a K-12 student, this user's movie viewing history over time is listed below. "

# %%
def return_user_details(uid):
    user = id2user[uid]
    item_seq, rating_seq = sequence_data[uid]
    cur_idx = lm_hist_idx[uid]
    hist_item_seq = item_seq[:cur_idx]
    hist_rating_seq = rating_seq[:cur_idx]
    history_texts = []
    movie_history = []
    for iid, rating in zip(hist_item_seq, hist_rating_seq):
        movie_history.append({'title': itemid2title[str(iid)], 'rating': rating})
    gender, age, occupation = user2attribute[uid]
    gender = GENDER_MAPPING[gender]
    age = AGE_MAPPING[age]
    occupation = OCCUPATION_MAPPING[occupation]
    return gender, age, occupation, movie_history

# %% [markdown]
# ## Identifying Classification Mistakes

# %%
train_loader = Data.DataLoader(dataset=train_set, batch_size=256, shuffle=False)
test_loader = Data.DataLoader(dataset=test_set, batch_size=256, shuffle=False)

# %%
auc, ll, loss, eval_time, labels, preds = eval(inference_model, train_loader) #short_loader
train_data['labels'] = labels
train_data['preds'] = preds

# %%
auc, ll, loss, eval_time, labels, preds = eval(inference_model, train_loader) #short_loader
print("train loss: %.5f, inference time: %.5f, auc: %.5f, logloss: %.5f" % (loss, eval_time, auc, ll))

preds_r = [1 if pred[0] > 0.5 else 0 for pred in preds]

mistake_indexes = [i for i, (label, pred) in enumerate(zip(labels, preds_r)) if label != pred]
mistake_indexes[:10]

# %%
data_list = []
for i in mistake_indexes:
    data = train_set[i]
    user_idx, user_hist = get_user_hist(data['hist_aug_vec'], hist_idxes)
    item_idx, item_desc = get_item_desc(data['item_aug_vec'], item_idxes)
    label = labels[i]
    pred = preds[i][0]
    data_list.append({'test_index': i, 'user_idx': user_idx, 'user_hist': user_hist, 'item_idx': item_idx, 'item_desc': item_desc, 'label': label, 'pred': pred})

df_results = pd.DataFrame(data_list)
df_results
# Out:
#         test_index user_idx  \
# 0                4     2336
# 1               18     1034
# 2               24     1034
# 3               29     1034
# 4               31     1034
# ...            ...      ...
# 209075      751414     4736
# 209076      751426     4736
# 209077      751427     4736
# 209078      751428     4736
# 209079      751433     4736
#
#                                                 user_hist item_idx  \
# 0       Given a male user who is aged 35-44 and a trad...     2922
# 1       Given a female user who is aged 35-44 and an a...      924
# 2       Given a female user who is aged 35-44 and an a...     1608
# 3       Given a female user who is aged 35-44 and an a...     3217
# 4       Given a female user who is aged 35-44 and an a...     1617
# ...                                                   ...      ...
# 209075  Given a male user who is aged 18-24 and a writ...     1792
# 209076  Given a male user who is aged 18-24 and a writ...     1060
# 209077  Given a male user who is aged 18-24 and a writ...     1061
# 209078  Given a male user who is aged 18-24 and a writ...      531
# 209079  Given a male user who is aged 18-24 and a writ...     2025
#
#                                                 item_desc  label      pred
# 0       Hang 'em High is a classic Western film releas...      0  0.774568
# 1       2001: A Space Odyssey is a science fiction fil...      0  0.716184
# 2       Air Force One is a 1997 action-thriller film d...      0  0.559843
# 3       "A Star is Born" is a 1937 American drama film...      1  0.384421
# 4       L.A. Confidential is a neo-noir crime film dir...      0  0.821938
# ...                                                   ...    ...       ...
# 209075  "U.S. Marshals" is a 1998 American action thri...      1  0.199561
# 209076  Swingers is a 1996 American comedy-drama film ...      0  0.554905
# 209077  Sleepers is a 1996 American legal crime drama ...      1  0.470843
# 209078  Sure, I'd be happy to introduce the movie Secr...      0  0.554470
# 209079  Lolita is a 1997 drama film directed by Adrian...      1  0.322678
#
# [209080 rows x 7 columns]

# %%
# df_results = pd.read_csv('/content/train_preds_labels.csv')
# df_results.to_csv('train_preds_labels.csv')

# %% [markdown]
# ## Encoding the text to vectors with BERT

# %%
from transformers import AutoTokenizer, AutoModel
from torch.utils.data import DataLoader
from lm_encoding import inference

tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased',  trust_remote_code=True)
encoding_model = AutoModel.from_pretrained('bert-base-uncased',  trust_remote_code=True).half().cuda()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %% [markdown]
# ### Validating the encoder

# %%
items = df_results['item_desc'].tolist()
item_loader = DataLoader(items[:4], 1, shuffle=False)

# %%
users = df_results['user_hist'].tolist()
user_loader = DataLoader(users[:1], 1, shuffle=False)

# %%
new_item_vec = inference(encoding_model, tokenizer, item_loader, 'bert', 'avg')
len(new_item_vec)
# Out:
# 100%|██████████| 4/4 [00:01<00:00,  2.27it/s]
# 4

# %%
new_user_vec = inference(encoding_model, tokenizer, user_loader, 'bert', 'avg')
len(new_user_vec)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 32.37it/s]
# 1

# %%
n_item_vec = [i for i in new_item_vec]
len(n_item_vec)
# Out:
# 4

# %%
for i in range(4):
    a = np.array(item_vec_dict[str(df_results['item_idx'][i])])
    b = np.array(new_item_vec[i])
    print(np.linalg.norm(a - b))
# Out:
# 0.003536781410996269
# 0.003649090919045039
# 0.0034479879603599322
# 0.0040963562191398675

# %%
for i in range(1):
    a = np.array(user_vec_dict[str(df_results['user_idx'][i])])
    b = np.array(new_user_vec[i])
    print(np.linalg.norm(a - b))
# Out:
# 0.003975717616505557

# %% [markdown]
# ## Loading LLM Model

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

torch.random.manual_seed(0)

model = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-3-mini-128k-instruct",
    device_map="cuda",
    torch_dtype="auto",
    trust_remote_code=True,
)
tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3-mini-128k-instruct")

messages = [
    {"role": "user", "content": "Can you provide ways to eat combinations of bananas and dragonfruits?"},
    {"role": "assistant", "content": "Sure! Here are some ways to eat bananas and dragonfruits together: 1. Banana and dragonfruit smoothie: Blend bananas and dragonfruits together with some milk and honey. 2. Banana and dragonfruit salad: Mix sliced bananas and dragonfruits together with some lemon juice and honey."},
    {"role": "user", "content": "What about solving an 2x + 3 = 7 equation?"},
]

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)

generation_args = {
    "max_new_tokens": 500,
    "return_full_text": False,
    "temperature": 0.0,
    "do_sample": False,
}

output = pipe(messages, **generation_args)
print(output[0]['generated_text'])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/3.35k [00:00<?, ?B/s]
# configuration_phi3.py:   0%|          | 0.00/10.4k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3-mini-128k-instruct:
# - configuration_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_phi3.py:   0%|          | 0.00/73.8k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3-mini-128k-instruct:
# - modeling_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# WARNING:transformers_modules.microsoft.Phi-3-mini-128k-instruct.8a362e755d2faf8cec2bf98850ce2216023d178a.modeling_phi3:`flash-attention` package not found, consider installing for better performance: No module named 'flash_attn'.
# WARNING:transformers_modules.microsoft.Phi-3-mini-128k-instruct.8a362e755d2faf8cec2bf98850ce2216023d178a.modeling_phi3:Current `flash-attenton` does not support `window_size`. Either upgrade or use `attn_implementation='eager'`.
# model.safetensors.index.json:   0%|          | 0.00/16.3k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.67G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/172 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/3.17k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/568 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:492: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# WARNING:transformers_modules.microsoft.Phi-3-mini-128k-instruct.8a362e755d2faf8cec2bf98850ce2216023d178a.modeling_phi3:You are not running the flash-attention implementation, expect numerical differences.
#  To solve the equation 2x + 3 = 7, you need to isolate the variable x. Here are the steps:
#
# 1. Subtract 3 from both sides of the equation to get rid of the +3 on the left side. This gives you: 2x = 7 - 3, which simplifies to 2x = 4.
#
# 2. Now, divide both sides of the equation by 2 to solve for x. This gives you: x = 4 / 2, which simplifies to x = 2.
#
# So, the solution to the equation 2x + 3 = 7 is x = 2.

# %%
from langchain import PromptTemplate, LLMChain
from langchain.llms import HuggingFacePipeline
from langchain_community.llms import HuggingFaceHub
# llm = HuggingFacePipeline(pipeline=pipe)
import os
os.environ['HUGGINGFACEHUB_API_TOKEN'] = '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'
llm = HuggingFaceHub(
    repo_id="microsoft/Phi-3-mini-128k-instruct",
    task="text-generation",
    model_kwargs={
        "max_new_tokens": 512,
        "top_k": 30,
        "temperature": 0.1,
        "repetition_penalty": 1.03,
    },
)

template = """Question: {question}
Answer:"""

prompt = PromptTemplate(
    input_variables=["question"],
    template=template
)

question = "Solve 2x + 3 = 7 equation?"

llm_chain = LLMChain(prompt=prompt, llm=llm)
llm_chain.run(question)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     303     try:
# --> 304         response.raise_for_status()
#     305     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/microsoft/Phi-3-mini-128k-instruct
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# <ipython-input-11-19e7ca258423> in <cell line: 29>()
#      27
#      28 llm_chain = LLMChain(prompt=prompt, llm=llm)
# ---> 29 llm_chain.run(question)
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     146                 warned = True
#     147                 emit_warning()
# --> 148             return wrapped(*args, **kwargs)
#     149
#     150         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     593             if len(args) != 1:
#     594                 raise ValueError("`run` supports only one positional argument.")
# --> 595             return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     596                 _output_key
#     597             ]
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     146                 warned = True
#     147                 emit_warning()
# --> 148             return wrapped(*args, **kwargs)
#     149
#     150         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     376         }
#     377
# --> 378         return self.invoke(
#     379             inputs,
#     380             cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     161         except BaseException as e:
#     162             run_manager.on_chain_error(e)
# --> 163             raise e
#     164         run_manager.on_chain_end(outputs)
#     165
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     151             self._validate_inputs(inputs)
#     152             outputs = (
# --> 153                 self._call(inputs, run_manager=run_manager)
#     154                 if new_arg_supported
#     155                 else self._call(inputs)
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py in _call(self, inputs, run_manager)
#     124         run_manager: Optional[CallbackManagerForChainRun] = None,
#     125     ) -> Dict[str, str]:
# --> 126         response = self.generate([inputs], run_manager=run_manager)
#     127         return self.create_outputs(response)[0]
#     128
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py in generate(self, input_list, run_manager)
#     136         callbacks = run_manager.get_child() if run_manager else None
#     137         if isinstance(self.llm, BaseLanguageModel):
# --> 138             return self.llm.generate_prompt(
#     139                 prompts,
#     140                 stop,
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/llms.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     631     ) -> LLMResult:
#     632         prompt_strings = [p.to_string() for p in prompts]
# --> 633         return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#     634
#     635     async def agenerate_prompt(
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/llms.py in generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     801                 )
#     802             ]
# --> 803             output = self._generate_helper(
#     804                 prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     805             )
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/llms.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     668             for run_manager in run_managers:
#     669                 run_manager.on_llm_error(e, response=LLMResult(generations=[]))
# --> 670             raise e
#     671         flattened_outputs = output.flatten()
#     672         for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/llms.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     655         try:
#     656             output = (
# --> 657                 self._generate(
#     658                     prompts,
#     659                     stop=stop,
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/llms.py in _generate(self, prompts, stop, run_manager, **kwargs)
#    1315         for prompt in prompts:
#    1316             text = (
# -> 1317                 self._call(prompt, stop=stop, run_manager=run_manager, **kwargs)
#    1318                 if new_arg_supported
#    1319                 else self._call(prompt, stop=stop, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/langchain_community/llms/huggingface_hub.py in _call(self, prompt, stop, run_manager, **kwargs)
#     133         parameters = {**_model_kwargs, **kwargs}
#     134
# --> 135         response = self.client.post(
#     136             json={"inputs": prompt, "parameters": parameters}, task=self.task
#     137         )
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/inference/_client.py in post(self, json, data, model, task, stream)
#     271
#     272             try:
# --> 273                 hf_raise_for_status(response)
#     274                 return response.iter_lines() if stream else response.content
#     275             except HTTPError as error:
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     369         # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     370         # as well (request id and/or server error message)
# --> 371         raise HfHubHTTPError(str(e), response=response) from e
#     372
#     373
#
# HfHubHTTPError: 429 Client Error: Too Many Requests for url: https://api-inference.huggingface.co/models/microsoft/Phi-3-mini-128k-instruct (Request ID: -r5BpaegCTw4SvrAyAyqA)
#
# Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate

# %% [markdown]
# ## Creating a Simple Reflexion Mechanism

# %%
import datetime
import os
from langchain_groq import ChatGroq

from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.pydantic_v1 import BaseModel, Field, ValidationError
from langchain_openai import ChatOpenAI
from langsmith import traceable

from collections import defaultdict
from typing import List

from langchain.output_parsers.openai_tools import (
    JsonOutputToolsParser,
    PydanticToolsParser,
)
from langchain_core.messages import AIMessage, BaseMessage, HumanMessage, ToolMessage
from langgraph.prebuilt.tool_executor import ToolExecutor, ToolInvocation

from dotenv import load_dotenv
load_dotenv(Path.cwd().joinpath('.env'))
# Out:
# True

# %%
def create_analysis_prompt(gender, age, occupation, movie_history):
    """
    Constructs a prompt for analyzing user preferences in movie recommendations,
    given limited data (only titles and ratings).

    Parameters:
    - gender (str): The gender of the user.
    - age (int): The age of the user.
    - occupation (str): The occupation of the user.
    - movie_history (list of dicts): A list of movies watched by the user,
                                     each entry is a dict with 'title' and 'rating'.

    Returns:
    - str: A detailed prompt for analysis.
    """
    prompt = f"Analyze the movie preferences of a {age}-year-old {gender} who works as a {occupation}. "
    prompt += "Consider their movie rating history and infer preferences from the following aspects:\n\n"

    # Titles and ratings summary
    titles_ratings = ', '.join([f"{movie['title']} (rated {movie['rating']}/5)" for movie in movie_history])
    prompt += f"- Movies and ratings: {titles_ratings}\n"

    # Encourage consideration of aspects where detailed data is not available
    prompt += "- Infer genres and subgenres from the movie titles.\n"
    prompt += "- Deduce potential favorite directors and actors based on common movie industry knowledge.\n"
    prompt += "- Assume preferences for film eras or years based on the release dates of the listed movies.\n"
    prompt += "- Consider common themes and motifs in these movies, such as love, conflict, adventure, etc.\n"
    prompt += "- Analyze the critical reception versus user ratings by considering how these types of films are generally received.\n"
    prompt += "- Predict preferences in sequels or franchises if any of the movies belong to such categories.\n"
    prompt += "- Consider how demographics (like age and gender) might influence the preferences inferred from the titles and ratings provided.\n"

    return prompt

# %%
def llm_revised_prompt(prompt_text,llm):
    system = "You are a helpful assistant in the movie recommendation domain."
    human = "{text}"
    prompt = ChatPromptTemplate.from_messages([("system", system), ("human", human)])

    chain = prompt | llm
    initial = chain.invoke({"text": prompt_text}).content
    return initial

# %%
uid_results = {}

# %%
# Out:
# ['1', '2', '3', '4', '5']

# %%
# Configure the LLM
llm = ChatOpenAI(api_key=os.getenv('OPENAI_API_KEY'), model='gpt-3.5-turbo-0125')

# Main loop for self-reflection based on user movie ratings
for uid in list(sequence_data.keys())[:5]:
    print(uid)
    gender, age, occupation, user_movie_history  = return_user_details(uid)
    iterations = 5
    results = []
    first = True
    for i in range(iterations,0,-1):
        # Create a slice of the movie history for the current iteration
        current_history = user_movie_history[:-i]  # Items 0 through i+5

        # Generate the analysis prompt
        if first:
            prompt = create_analysis_prompt(gender, age, occupation, current_history)
            # Ask the LLM for analysis
            analysis = llm_revised_prompt(prompt,llm)
            first = False

        # Predict the rating for the next movie
        answer_according_to_analysis = llm_revised_prompt(f"""According to this analysis: {analysis}
                                                            What would be the rating for: {user_movie_history[-i]['title']}?
                                                            Answer with a single number between 1 and 5 - mark it with * before and after * the rating, like this
                                                            The rating will be: *5* """,llm)
        extract_rating = re.search(r"\*(\d+)\*", answer_according_to_analysis)
        next_movie_rating = int(extract_rating.group(1))

        # Check if the prediction matches the actual rating
        actual_rating = user_movie_history[-i]['rating']
        print(next_movie_rating,actual_rating)
        # Provide feedback and refine if necessary
        if next_movie_rating != actual_rating:
            feedback_prompt = f"""According to this analysis: {analysis}.
                                  The model predicted {next_movie_rating} but the expected rating was {actual_rating}.
                                  Please adjust your analysis.
                                  Remember here are the guidelines:
                                  {prompt}"""
            new_analysis = llm_revised_prompt(feedback_prompt,llm)
            results.append((analysis, answer_according_to_analysis, next_movie_rating, actual_rating,new_analysis))
            analysis = new_analysis
        else:
            print("No feedback needed.")
            results.append((analysis, answer_according_to_analysis, next_movie_rating, actual_rating,None))

    print(results)
    uid_results[uid] = results
# Out:
# 1
# 4 3
# 3 3
# No feedback needed.
# 4 3
# 3 3
# No feedback needed.
# 4 4
# No feedback needed.
# [("Based on the movie ratings provided by the under 18-year-old female K-12 student, we can infer the following preferences:\n\nGenres and Subgenres:\n1. Drama: Music of the Heart, The Insider, Fried Green Tomatoes, The Unbearable Lightness of Being, Dead Again, Men Don't Leave, Felicia's Journey, The Thin Red Line\n2. Thriller: Ghost, The Bone Collector, The Silence of the Lambs, Mortal Thoughts\n3. Action: The Rock, Eraser, Air Force One\n4. Romance: Fried Green Tomatoes, Raise the Red Lantern, Edward Scissorhands, Playing by Heart\n5. Crime: L.A. Confidential, Donnie Brasco\n6. Mystery: Dead Again, Spellbound\n7. Horror: Mimic, Poison Ivy\n8. Historical Drama: Raise the Red Lantern, The Thin Red Line\n9. Biographical Drama: The Insider, Music of the Heart\n10. Psychological Thriller: The Silence of the Lambs\n\nFavorite Directors and Actors:\n- Potential favorite directors could include Steven Spielberg (Ghost), Jonathan Demme (The Silence of the Lambs), Tim Burton (Edward Scissorhands), and Michael Mann (The Insider).\n- Common actors in the listed movies are likely to include Anthony Hopkins, Jodie Foster, Michelle Pfeiffer, Johnny Depp, and Meryl Streep.\n\nFilm Eras or Years:\nThe listed movies span a range of years from 1945 (Spellbound) to 1999 (Music of the Heart, Felicia's Journey, Mansfield Park). Based on this, the individual may have a preference for movies from the late 80s to late 90s.\n\nThemes and Motifs:\nThemes such as love, relationships, psychological depth, crime, and drama are prevalent in the listed movies. The individual seems to enjoy movies with complex characters and emotional depth.\n\nCritical Reception vs. User Ratings:\nThe individual tends to rate movies higher than average, with most ratings falling between 3 and 5. This suggests a preference for well-received films that resonate emotionally.\n\nSequels or Franchises:\nNone of the listed movies belong to sequels or franchises; however, if the individual enjoys a particular movie, she may be inclined to explore related sequels or franchises within the same genre.\n\nDemographics Influence:\nAs an under 18-year-old female K-12 student, her preferences may be influenced by themes of personal growth, relationships, and societal issues depicted in the movies. She may also appreciate strong character development and emotionally engaging narratives.", 'The rating for Malcolm X (1992) based on the provided analysis would likely be: *4*', 4, 3, "Based on the movie ratings provided by the under 18-year-old female K-12 student, we can infer the following preferences:\n\nGenres and Subgenres:\n1. Drama: Music of the Heart, Fried Green Tomatoes, The Unbearable Lightness of Being, Dead Again, Men Don't Leave, Felicia's Journey, The Thin Red Line\n2. Thriller: Ghost, The Bone Collector, The Silence of the Lambs, Mortal Thoughts\n3. Action: The Rock, Eraser, Air Force One\n4. Romance: Fried Green Tomatoes, Raise the Red Lantern, Edward Scissorhands, Playing by Heart\n5. Crime: L.A. Confidential, Donnie Brasco\n6. Horror: Mimic, Poison Ivy\n7. Mystery: Dead Again, Spellbound\n8. Historical Drama: Raise the Red Lantern, The Thin Red Line\n\nFavorite Directors and Actors:\n- Potential favorite directors could include Jonathan Demme (The Silence of the Lambs), Tim Burton (Edward Scissorhands), and Michael Mann (The Insider).\n- Common actors in the listed movies are likely to include Jodie Foster, Michelle Pfeiffer, Johnny Depp, and Meryl Streep.\n\nFilm Eras or Years:\nThe listed movies span a range of years from 1945 (Spellbound) to 1999 (Music of the Heart, Felicia's Journey, Mansfield Park). Based on this, the individual may have a preference for movies from the late 80s to late 90s.\n\nThemes and Motifs:\nThemes such as love, relationships, psychological depth, crime, and drama are prevalent in the listed movies. The individual seems to enjoy movies with complex characters and emotional depth.\n\nCritical Reception vs. User Ratings:\nThe individual tends to ...
# 2
# 4 5
# 4 3
# 4 5
# 4 3
# 4 5
# [('Based on the movie preferences of the 56+-year-old male who works as self-employed, we can infer the following:\n\nGenres and Subgenres:\n1. Classic Films: The majority of the movies listed are classic films released between the 1930s and 1990s, indicating a preference for timeless cinema.\n2. War Films: Movies like "The Bridge on the River Kwai" and "Dances with Wolves" suggest an interest in war-themed films.\n3. Comedy: Comedies like "Duck Soup," "Young Frankenstein," "Some Like It Hot," and "Animal House" indicate a preference for comedy films.\n4. Drama: The inclusion of movies like "Gone with the Wind," "It\'s a Wonderful Life," and "Mr. Smith Goes to Washington" suggests a liking for dramatic storytelling.\n5. Mystery/Thriller: Movies like "Chinatown," "Rear Window," and "Witness" indicate an attraction to mystery and thriller genres.\n\nFavorite Directors and Actors:\n- Favorite Directors: Given the selection of classic films, the individual may appreciate directors like Alfred Hitchcock, Frank Capra, and Billy Wilder.\n- Favorite Actors: Actors such as Humphrey Bogart, Jimmy Stewart, Cary Grant, and Clark Gable are likely to be among the favorites based on the movies listed.\n\nFilm Eras or Years:\nThe individual seems to have a preference for movies spanning several decades, from the 1930s to the 1990s. This indicates an appreciation for the golden age of cinema and classic storytelling.\n\nThemes and Motifs:\nCommon themes in the listed movies include love, conflict, adventure, and social commentary. These themes resonate with classic storytelling elements that explore human emotions and societal issues.\n\nCritical Reception vs. User Ratings:\nThe high ratings given to most of the movies suggest a strong personal liking for these films, which may align with critical reception. This indicates a taste for well-crafted, critically acclaimed movies.\n\nSequels or Franchises:\nGiven the selection of standalone classic films, there are no clear preferences for sequels or franchises. The individual seems to appreciate standalone, self-contained stories.\n\nDemographics Influence:\nThe preferences of the individual are influenced by their age and gender, leading to a liking for classic films, war dramas, comedies, and mysteries that resonate with a mature audience with a diverse taste in cinema.', 'The rating for "The War of the Worlds" (1953) would be: *4*', 4, 5, 'Based on the movie preferences of the 56+-year-old male who works as self-employed, here is an adjusted analysis:\n\nGenres and Subgenres:\n1. Classic Films: The individual clearly has a strong preference for classic films spanning multiple decades, from the 1930s to the 1990s.\n2. War Films: The inclusion of movies like "The Bridge on the River Kwai," "Dances with Wolves," and "Casablanca" suggests an interest in war-themed films.\n3. Comedy: Comedies like "Duck Soup," "Young Frankenstein," "Some Like It Hot," and "Animal House" are among the favorite genres.\n4. Drama: The individual appreciates dramatic storytelling as seen in movies like "Gone with the Wind," "It\'s a Wonderful Life," and "Mr. Smith Goes to Washington."\n5. Mystery/Thriller: The selection of movies like "Chinatown," "Rear Window," and "Witness" indicates an attraction to mystery and thriller genres.\n\nFavorite Directors and Actors:\n- Favorite Directors: Given the love for classic films, the individual may favor directors like Alfred Hitchcock, Frank Capra, and Billy Wilder.\n- Favorite Actors: Actors such as Humphrey Bogart, Jimmy Stewart, and Cary Grant are likely to be among the favorites based on the movies listed.\n\nFilm Eras or Years:\nThe individual shows a clear preference for movies from various eras, indicating an appreciation for the golden age of cinema and classic storytelling.\n\nThemes and Motifs:\nCommon themes in the listed movies include love, conflict, adventure, and social commentary, resonating with classic storytelling elements that explore human emotions and soci ...
# 3
# 4 4
# No feedback needed.
# 4 5
# 4 5
# 3 5
# 5 5
# No feedback needed.
# [('Based on the movie preferences of the 25-34-year-old male scientist, we can infer the following:\n\n1. **Genres and Subgenres**:\n   - **Toy Story (1995)**: Animated, Family, Adventure\n   - **Groundhog Day (1993)**: Comedy, Fantasy\n   - **A Close Shave (1995)**: Animation, Comedy, Family\n   - **L.A. Confidential (1997)**: Crime, Drama, Mystery\n   - **His Girl Friday (1940)**: Comedy, Romance\n   - **Edward Scissorhands (1990)**: Drama, Fantasy, Romance\n\n2. **Favorite Directors and Actors**:\n   - Potential favorite directors could include Steven Spielberg (for Toy Story), Tim Burton (for Edward Scissorhands), and Billy Wilder (for His Girl Friday).\n   - Common actors in these movies include Tom Hanks (voice in Toy Story), Bill Murray (Groundhog Day), Johnny Depp (Edward Scissorhands), and Kim Basinger (L.A. Confidential).\n\n3. **Film Eras or Years**:\n   - The scientist seems to enjoy a mix of classic (His Girl Friday), 90s (Toy Story, Groundhog Day, A Close Shave) and 2000s (L.A. Confidential) films.\n\n4. **Themes and Motifs**:\n   - Common themes in these movies include friendship (Toy Story), redemption (Edward Scissorhands), crime (L.A. Confidential), and love (His Girl Friday).\n\n5. **Critical Reception vs User Ratings**:\n   - The movies listed generally have high ratings, indicating that they are well-received by both critics and audiences.\n\n6. **Preferences in Sequels or Franchises**:\n   - Given the positive ratings for Toy Story and potential interest in animated films, the scientist may enjoy sequels or other movies in the Toy Story franchise.\n\n7. **Influence of Demographics**:\n   - As a 25-34-year-old male scientist, his movie preferences seem to lean towards a mix of classic and contemporary films with a focus on genres like animation, comedy, drama, and fantasy.\n\nOverall, the scientist seems to have a diverse taste in movies, appreciating a mix of genres, eras, and themes. He values well-crafted stories with strong character development and engaging narratives. The positive ratings suggest that he enjoys movies that are well-received by both critics and audiences alike.', 'The rating for **Creature Comforts (1990)** would be: *4*', 4, 4, None), ('Based on the movie preferences of the 25-34-year-old male scientist, we can infer the following:\n\n1. **Genres and Subgenres**:\n   - **Toy Story (1995)**: Animated, Family, Adventure\n   - **Groundhog Day (1993)**: Comedy, Fantasy\n   - **A Close Shave (1995)**: Animation, Comedy, Family\n   - **L.A. Confidential (1997)**: Crime, Drama, Mystery\n   - **His Girl Friday (1940)**: Comedy, Romance\n   - **Edward Scissorhands (1990)**: Drama, Fantasy, Romance\n\n2. **Favorite Directors and Actors**:\n   - Potential favorite directors could include Steven Spielberg (for Toy Story), Tim Burton (for Edward Scissorhands), and Billy Wilder (for His Girl Friday).\n   - Common actors in these movies include Tom Hanks (voice in Toy Story), Bill Murray (Groundhog Day), Johnny Depp (Edward Scissorhands), and Kim Basinger (L.A. Confidential).\n\n3. **Film Eras or Years**:\n   - The scientist seems to enjoy a mix of classic (His Girl Friday), 90s (Toy Story, Groundhog Day, A Close Shave) and 2000s (L.A. Confidential) films.\n\n4. **Themes and Motifs**:\n   - Common themes in these movies include friendship (Toy Story), redemption (Edward Scissorhands), crime (L.A. Confidential), and love (His Girl Friday).\n\n5. **Critical Reception vs User Ratings**:\n   - The movies listed generally have high ratings, indicating that they are well-received by both critics and audiences.\n\n6. **Preferences in Sequels or Franchises**:\n   - Given the positive ratings for Toy Story and potential interest in animated films, the scientist may enjoy sequels or other movies in the Toy Story franchise.\n\n7. **Influence of Demographics**:\n   - As a 25-34-year-old male scientist, his movie preferences seem to lean towards a mix of classic and contemporary films with a focus on genres lik ...
# 4
# 2 4
# 3 4
# 2 2
# No feedback needed.
# 4 3
# 4 2
# [("Based on the movie preferences of the 45-49-year-old male executive/managerial, we can infer the following:\n\nGenres and subgenres:\n1. Action: Terminator 2: Judgment Day, The Rock, Air Force One, Rambo series\n2. Thriller: The Negotiator, The Silence of the Lambs, L.A. Confidential\n3. Adventure: Indiana Jones and the Last Crusade, Romancing the Stone, The Jewel of the Nile\n4. Sci-Fi/Fantasy: X-Men, Independence Day\n5. Historical: Gandhi, The Great Escape\n6. Mystery: The Hunt for Red October\n\nFavorite directors and actors:\n1. Director: Steven Spielberg (Back to the Future, Indiana Jones and the Last Crusade), James Cameron (Terminator 2: Judgment Day), Ridley Scott (The Jewel of the Nile)\n2. Actors: Harrison Ford, Sean Connery, Anthony Hopkins\n\nFilm eras or years:\nThe individual seems to have a preference for movies from the 1980s and 1990s, with a few classics from the 1960s and 1980s.\n\nCommon themes and motifs:\nThe individual seems to enjoy movies with elements of action, suspense, heroism, and adventure. They also appreciate films with strong character development and engaging storylines.\n\nCritical reception versus user ratings:\nThe individual tends to rate movies higher that are well-received critically, such as The Silence of the Lambs and L.A. Confidential, indicating a preference for quality filmmaking.\n\nPreferences in sequels or franchises:\nGiven the ratings for Terminator 2: Judgment Day and Rambo series, it can be inferred that the individual enjoys sequels or franchises with consistent quality and action.\n\nDemographics influence:\nAs a middle-aged male executive, the individual's preferences align with typical male-oriented genres like action, thriller, and adventure. The nostalgic value of movies from the 80s and 90s may also play a role in their movie choices.\n\nOverall, the individual enjoys a mix of action-packed thrillers, historical dramas, and adventurous classics, with a preference for well-crafted storytelling and engaging performances.", 'The rating for Anaconda (1997) based on the preferences and analysis provided would be:\n\n*2*', 2, 4, "Based on the movie preferences and ratings provided by the 45-49-year-old male executive/managerial individual, we can infer the following:\n\nGenres and subgenres:\n1. Action: Terminator 2: Judgment Day, The Rock, Air Force One, Rambo series, Eraser\n2. Thriller: The Negotiator, The Silence of the Lambs, L.A. Confidential, Ronin\n3. Adventure: Indiana Jones and the Last Crusade, Romancing the Stone, The Jewel of the Nile\n4. Sci-Fi/Fantasy: X-Men, Independence Day\n5. Historical: Gandhi, The Great Escape\n6. Comedy: Back to the Future, Say Anything...\n7. Mystery: The Hunt for Red October\n\nFavorite directors and actors:\n1. Director: Steven Spielberg, James Cameron, Ridley Scott\n2. Actors: Harrison Ford, Sean Connery, Anthony Hopkins\n\nFilm eras or years:\nThe individual seems to have a preference for movies from the 1980s and 1990s, with a sprinkling of classics from the 1960s.\n\nCommon themes and motifs:\nThe individual enjoys movies with elements of action, suspense, heroism, adventure, and strong character development. They appreciate engaging storylines and well-crafted storytelling.\n\nCritical reception versus user ratings:\nThe individual tends to rate movies higher that are well-received critically, indicating a preference for quality filmmaking. Movies like The Silence of the Lambs, L.A. Confidential, and The Hunt for Red October received top ratings.\n\nPreferences in sequels or franchises:\nThe individual seems to enjoy sequels or franchises with consistent quality and action, as evidenced by ratings for Terminator 2: Judgment Day and Rambo series movies.\n\nDemographics influence:\nAs a middle-aged male executive, the individual's preferences align with typical male-oriented genres like action, thriller, and adventure. The nostalgia factor of movies from the 80s and 90s likely plays a role in their movie choices.\n\nOverall, ...
# 5
# 4 5
# 4 4
# No feedback needed.
# 4 4
# No feedback needed.
# 4 4
# No feedback needed.
# 3 4
# [("Based on the provided movie ratings and the given information about the individual being a 25-34-year-old male writer, we can infer the following preferences:\n\nGenres and Subgenres:\n1. **Drama**: American Beauty (1999), Some Folks Call It a Sling Blade (1993)\n2. **Fantasy**: Sleepy Hollow (1999), The Nightmare Before Christmas (1993)\n3. **Comedy**: Galaxy Quest (1999), Back to the Future (1985), Office Space (1999), Clerks (1994)\n4. **Adventure**: X-Men (2000), The 13th Warrior (1999)\n5. **Animation**: Toy Story 2 (1999), Stuart Little (1999)\n6. **Sci-Fi**: E.T. the Extra-Terrestrial (1982), X-Men (2000)\n7. **Thriller**: The Ninth Gate (2000), Payback (1999)\n\nFavorite Directors and Actors:\n1. **Director**: Tim Burton (Sleepy Hollow, The Nightmare Before Christmas), Steven Spielberg (E.T. the Extra-Terrestrial), Kevin Smith (Clerks, Dogma)\n2. **Actor**: Johnny Depp (Sleepy Hollow), Kevin Spacey (American Beauty), Keanu Reeves (The Matrix)\n\nFilm Eras or Years:\nThe individual seems to enjoy movies mainly from the 1980s to early 2000s based on the release dates of the listed movies.\n\nCommon Themes and Motifs:\nThemes like dark humor, unconventional storytelling, fantasy elements, and exploration of human nature seem to resonate with this individual.\n\nCritical Reception vs. User Ratings:\nThe individual seems to enjoy a mix of critically acclaimed films (American Beauty, Some Folks Call It a Sling Blade) and more light-hearted, popular movies (Back to the Future, Toy Story 2).\n\nPreference in Sequels or Franchises:\nGiven the ratings for movies like X-Men (2000) and Toy Story 2 (1999), there might be a preference for sequels or franchises within those genres.\n\nInfluence of Demographics:\nAs a 25-34-year-old male writer, the individual's preferences seem to lean towards a mix of thought-provoking dramas, fantasy adventures, and nostalgic comedies that align with the typical interests of this demographic group.\n\nOverall, the individual appears to have a diverse taste in movies, showing an appreciation for a variety of genres, themes, and film styles.", 'The rating for *The Talented Mr. Ripley (1999)* would be *4*.', 4, 5, "Based on the updated movie ratings and the information provided about the individual being a 25-34-year-old male writer, here is an adjusted analysis of his movie preferences:\n\nGenres and Subgenres:\n1. **Drama**: American Beauty (1999) (5/5), Some Folks Call It a Sling Blade (1993) (4/5)\n2. **Fantasy**: Sleepy Hollow (1999) (4/5), The Nightmare Before Christmas (1993) (4/5)\n3. **Comedy**: Galaxy Quest (1999) (4/5), Back to the Future (1985) (4/5), Office Space (1999) (4/5), Clerks (1994) (3/5)\n4. **Adventure**: X-Men (2000) (4/5), The 13th Warrior (1999) (3/5)\n5. **Animation**: Toy Story 2 (1999) (5/5), Stuart Little (1999) (3/5)\n6. **Sci-Fi**: E.T. the Extra-Terrestrial (1982) (4/5), X-Men (2000) (4/5)\n7. **Thriller**: The Ninth Gate (2000) (2/5)\n\nFavorite Directors and Actors:\n1. **Director**: Tim Burton (Sleepy Hollow, The Nightmare Before Christmas), Kevin Smith (Clerks)\n2. **Actor**: Johnny Depp (Sleepy Hollow), Kevin Spacey (American Beauty)\n\nFilm Eras or Years:\nThe individual seems to enjoy movies from the 1980s to early 2000s based on the release dates of the listed movies.\n\nCommon Themes and Motifs:\nThemes like dark humor, fantasy elements, and exploration of human nature seem to resonate with this individual.\n\nCritical Reception vs. User Ratings:\nThe individual seems to enjoy a mix of critically acclaimed films (American Beauty) and popular movies (Back to the Future, Toy Story 2) based on the ratings provided.\n\nPreference in Sequels or Franchises:\nGiven the high ratings for Toy Story 2 and X-Men, there might be a preference for sequels or franchises within those genres.\n\nInfluence of Demographics:\nAs a 25-34-year-old male writer, the individual's preferences align with a mix of thought-provoking dramas, fantasy adventures, and nostalgic comedies tha ...

# %%
uid_results['2'][0][0]
# Out:
# 'Based on the movie preferences of the 56+-year-old male who works as self-employed, we can infer the following:\n\nGenres and Subgenres:\n1. Classic Films: The majority of the movies listed are classic films released between the 1930s and 1990s, indicating a preference for timeless cinema.\n2. War Films: Movies like "The Bridge on the River Kwai" and "Dances with Wolves" suggest an interest in war-themed films.\n3. Comedy: Comedies like "Duck Soup," "Young Frankenstein," "Some Like It Hot," and "Animal House" indicate a preference for comedy films.\n4. Drama: The inclusion of movies like "Gone with the Wind," "It\'s a Wonderful Life," and "Mr. Smith Goes to Washington" suggests a liking for dramatic storytelling.\n5. Mystery/Thriller: Movies like "Chinatown," "Rear Window," and "Witness" indicate an attraction to mystery and thriller genres.\n\nFavorite Directors and Actors:\n- Favorite Directors: Given the selection of classic films, the individual may appreciate directors like Alfred Hitchcock, Frank Capra, and Billy Wilder.\n- Favorite Actors: Actors such as Humphrey Bogart, Jimmy Stewart, Cary Grant, and Clark Gable are likely to be among the favorites based on the movies listed.\n\nFilm Eras or Years:\nThe individual seems to have a preference for movies spanning several decades, from the 1930s to the 1990s. This indicates an appreciation for the golden age of cinema and classic storytelling.\n\nThemes and Motifs:\nCommon themes in the listed movies include love, conflict, adventure, and social commentary. These themes resonate with classic storytelling elements that explore human emotions and societal issues.\n\nCritical Reception vs. User Ratings:\nThe high ratings given to most of the movies suggest a strong personal liking for these films, which may align with critical reception. This indicates a taste for well-crafted, critically acclaimed movies.\n\nSequels or Franchises:\nGiven the selection of standalone classic films, there are no clear preferences for sequels or franchises. The individual seems to appreciate standalone, self-contained stories.\n\nDemographics Influence:\nThe preferences of the individual are influenced by their age and gender, leading to a liking for classic films, war dramas, comedies, and mysteries that resonate with a mature audience with a diverse taste in cinema.'

# %%
uid_results['2'][-1][-1]
# Out:
# 'Based on the movie preferences and ratings provided by the 56+-year-old male who works as self-employed, here is an adjusted analysis:\n\nGenres and Subgenres:\n1. Classic Films: The individual has a strong affinity for classic films spanning different decades, evident from movies like "Casablanca," "Gone with the Wind," "It\'s a Wonderful Life," and "The Wizard of Oz."\n2. War Films: The inclusion of movies like "The Bridge on the River Kwai," "Dances with Wolves," and "Mr. Smith Goes to Washington" indicates an interest in war-themed or politically charged films.\n3. Comedy: Comedies such as "Duck Soup," "Young Frankenstein," "Some Like It Hot," and "Animal House" are among the favorites, highlighting a preference for humor and witty storytelling.\n4. Mystery/Thriller: Movies like "Chinatown," "Rear Window," and "Witness" suggest a liking for mystery and thriller genres with engaging plots.\n\nFavorite Directors and Actors:\n- Favorite Directors: It is likely that the individual appreciates directors like Alfred Hitchcock (e.g., "Rear Window"), Frank Capra (e.g., "It\'s a Wonderful Life"), and Mel Brooks (e.g., "Young Frankenstein") based on the listed movies.\n- Favorite Actors: Actors such as Cary Grant (e.g., "Arsenic and Old Lace"), Humphrey Bogart (e.g., "Casablanca"), and Jimmy Stewart (e.g., "Mr. Smith Goes to Washington") are probable favorites according to the movie choices.\n\nFilm Eras or Years:\nThe individual\'s preference for movies from various eras signifies an admiration for the golden age of cinema and classic storytelling.\n\nThemes and Motifs:\nCommon themes in the listed movies include love, conflict, adventure, social commentary, and humor, reflecting classic storytelling elements exploring human emotions and societal issues.\n\nCritical Reception vs. User Ratings:\nThe high ratings given to most movies suggest a strong personal fondness for these films, aligning with critical reception and indicating a preference for well-crafted, critically acclaimed movies.\n\nSequels or Franchises:\nGiven the selection of standalone classic films, there seems to be no clear preference for sequels or franchises. The individual appears to enjoy standalone, self-contained stories.\n\nDemographics Influence:\nThe individual\'s preferences are influenced by their age and gender, leading to a preference for classic films, war dramas, comedies, and mysteries that resonate with a mature audience with a diverse taste in cinema.\n\nOverall, the individual showcases a diverse range of preferences encompassing classic, war, comedy, and mystery genres, indicating a deep appreciation for well-crafted storytelling and performances across different eras of cinema.'

# %%
#save dict to jason
# import json
# with open('uid_results.json', 'w') as f:
#     json.dump(uid_results, f)
# uid_results

# %%
answer_according_to_analysis = llm_revised_prompt(f"""According to this analysis: {analysis}
                                                    What would be the rating for: {user_movie_history[-i]['title']}?
                                                    Answer with a single number between 1 and 5 - mark it with * before and after * the rating, like this
                                                    The rating will be: *5* """,llm)
extract_rating = re.search(r"\*(\d+)\*", answer_according_to_analysis)
next_movie_rating = int(extract_rating.group(1))

# Check if the prediction matches the actual rating
actual_rating = user_movie_history[i+6]['rating']

# %%
extract_rating.group(1)
# Out:
# '4'

# %%
user_movie_history[i+6]['rating']
# Out:
# 4

# %%
parser = JsonOutputToolsParser(return_id=True)

# %%
actor_prompt_template = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """You are expert researcher.
            Current time: {time}

            1. {first_instruction}
            2. Reflect and critique your answer. Be severe to maximize improvement.
            3. Recommend search queries to research information and improve your answer.""",
        ),
            MessagesPlaceholder(variable_name="messages"),
            ("system", "Answer the user's question above using the required format."),
        ]
).partial(
    time=lambda: datetime.datetime.now().isoformat(),
)


class Reflection(BaseModel):
    missing: str = Field(description="Critique of what is missing.")
    superfluous: str = Field(description="Critique of what is superfluous")


class AnswerQuestion(BaseModel):
    """Answer the question."""

    answer: str = Field(description="~250 word detailed answer to the question.")
    reflection: Reflection = Field(description="Your reflection on the initial answer.")
    search_queries: List[str] = Field(
        description="1-3 search queries for researching improvements to address the critique of your current answer."
    )

# %%
# llm = ChatGroq(groq_api_key = os.getenv('GROQ_API_KEY'),model = 'llama3-8b-8192')
llm = ChatOpenAI(api_key=os.getenv('OPENAI_API_KEY'), model='gpt-3.5-turbo-0125') # gpt-4-turbo-2024-04-09
initial_answer_chain = actor_prompt_template.partial(
    first_instruction="Provide a detailed answer."
) | llm.bind_tools(tools=[AnswerQuestion], tool_choice="AnswerQuestion")
validator = PydanticToolsParser(tools=[AnswerQuestion])

# %%
class ResponderWithRetries:
    def __init__(self, runnable, validator):
        self.runnable = runnable
        self.validator = validator

    @traceable
    def respond(self, state: List[BaseMessage]):
        response = []
        for attempt in range(3):
            try:
                response = self.runnable.invoke({"messages": state})
                self.validator.invoke(response)
                return response
            except ValidationError as e:
                state = state + [HumanMessage(content=repr(e))]
        return response

first_responder = ResponderWithRetries(
    runnable=initial_answer_chain, validator=validator
)

# %%
round(df_results['pred'][0])
# Out:
# 1

# %%
def generate_prompt_from_df(row):
    user_hist = row['user_hist']
    item_desc = row['item_desc']
    real_label = row['label']
    pred = round(row['pred'])
    prompt =    f"""User has the following history: {user_hist}.
                    Item has the following description: {item_desc}.
                    A mistake was made in the model's prediction.
                    The real label is {real_label} and the model predicted {pred}.
                    How would you rephrase the user history and item description to improve the model's prediction?
                    Answer formst should like this:
                    Revised User History: <revised user history> \n\n
                    Revised Item Description: <revised item description>
                    use two lines at the end of user history and at the end of item description.
                    Remember that your new rephrasing should help the model to predict better next time but without overfitting"""
    return prompt

# %%
# def generate_prompt_from_df(df_restuls,idx):
#     user_hist = df_restuls['user_hist'][idx]
#     item_desc = df_restuls['item_desc'][idx]
#     real_label = df_restuls['label'][idx]
#     pred = df_restuls['pred'][idx]

#     prompt =    f"""Task:Rephrase the user history and item description to better match the prediction to the actual label. Assume that the model's prediction is either a match or a mismatch to the label, and modify the descriptions to improve the fit between user preferences (as inferred from the user history) and the characteristics of the movie (as described in the item description).

#                 Output Format:
#                 Revised User History:
#                 Try to rephrase the user history to better reflect the user's preferences.
#                 You can adjust the length, tone, and content of the user history to better align with the user's likely interests.
#                 Finish the Revised User History with ;
#                 Revised Item Description:
#                 The item description should be rephrased to highlight aspects of the movie that are more aligned with the user's adjusted preferences.
#                 Key elements to focus on might include genre, notable performances, thematic elements, and any particular production features.
#                 Finish the Revised User Item Description with ;

#                 Here is the user history: {user_hist}.
#                 Here is the item description: {item_desc}.
#                 A mistake was made in the model's prediction.
#                 The real label is {real_label} and the model predicted {pred}.
#                 How would you rephrase the user history and item description to improve the model's prediction?

#                 """
#     return prompt

# %%
def extract_revised_prompt(initial):
  revised_prompt = initial.content + ";"
  # String containing the revised User History and Revised Item Description
  # Extracting the revised User History
  user_history = re.search(r"Revised User History:\n(.*?)\n\n", revised_prompt, re.DOTALL)
  if user_history:
      user_history = user_history.group(1).strip()

  # Extracting the Revised Item Description
  item_description = re.search(r"Revised Item Description:\n(.*?);", revised_prompt, re.DOTALL)
  if item_description:
      item_description = item_description.group(1).strip()

  # Printing the extracted information
  # print("Revised User History:", user_history)
  # print("Revised Item Description:", item_description)
  return user_history, item_description

# %%
def reflect_prompt(row):
    prompt = generate_prompt_from_df(row)
    initial = llm_revised_prompt(prompt)
    user_history, item_description = extract_revised_prompt(initial)
    return user_history, item_description, initial.content

# %%
df_results['user_idx'].value_counts()
# Out:
# user_idx
# 1680    618
# 1941    465
# 2909    444
# 3841    415
# 2907    353
#        ...
# 2510      1
# 3104      1
# 4228      1
# 4129      1
# 2336      1
# Name: count, Length: 5382, dtype: int64

# %%
sub_df = df_results.iloc[:30]
sub_df['user_reflect'] = ""
sub_df['item_reflect'] = ""
sub_df['init_context'] = ""
# Out:
# <ipython-input-43-22e6b2741323>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['user_reflect'] = ""
# <ipython-input-43-22e6b2741323>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['item_reflect'] = ""
# <ipython-input-43-22e6b2741323>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['init_context'] = ""

# %%
u_list =[]
i_list = []
for i, row in sub_df.iterrows():
    user_history, item_description, init_context = reflect_prompt(row)
    sub_df.loc[i,'user_reflect'] = user_history
    sub_df.loc[i,'item_reflect'] = item_description
    sub_df.loc[i,'init_context'] = init_context

# %%
sub_df_clean = sub_df.dropna()
sub_df_clean.reset_index(drop=True, inplace=True)
sub_df_clean
# Out:
#     test_index user_idx                                          user_hist  \
# 0           29     1034  Given a female user who is aged 35-44 and an a...
# 1           34     1034  Given a female user who is aged 35-44 and an a...
# 2           39     1034  Given a female user who is aged 35-44 and an a...
# 3           59     1034  Given a female user who is aged 35-44 and an a...
# 4           60     1034  Given a female user who is aged 35-44 and an a...
# 5           65     1034  Given a female user who is aged 35-44 and an a...
# 6           79     1034  Given a female user who is aged 35-44 and an a...
# 7           84     1034  Given a female user who is aged 35-44 and an a...
# 8           86     1034  Given a female user who is aged 35-44 and an a...
# 9           87     1034  Given a female user who is aged 35-44 and an a...
# 10          88     1034  Given a female user who is aged 35-44 and an a...
# 11          90     1034  Given a female user who is aged 35-44 and an a...
# 12          94     1034  Given a female user who is aged 35-44 and an a...
# 13          96     1034  Given a female user who is aged 35-44 and an a...
# 14          97     1034  Given a female user who is aged 35-44 and an a...
# 15          99     1034  Given a female user who is aged 35-44 and an a...
# 16         100     1034  Given a female user who is aged 35-44 and an a...
# 17         105     1034  Given a female user who is aged 35-44 and an a...
#
#    item_idx                                          item_desc  label  \
# 0      3217  "A Star is Born" is a 1937 American drama film...      1
# 1      2278  Ronin is a 1998 thriller movie directed by Joh...      0
# 2       949  East of Eden is a classic drama film released ...      0
# 3      3408  Erin Brockovich is a biographical drama film t...      1
# 4      2617  The Mummy is a 1999 American action-adventure ...      1
# 5      2640  Superman is a 1978 superhero film directed by ...      1
# 6      2861  For Love of the Game is a romantic sports dram...      1
# 7       477  What's Love Got to Do with It? is a 1993 biogr...      0
# 8      2100  Splash is a romantic comedy film released in 1...      1
# 9      3844  Steel Magnolias is a 1989 American comedy-dram...      1
# 10     2110  Dead Men Don't Wear Plaid is a 1982 comedy fil...      1
# 11     1333  The Birds is a 1963 horror-thriller film direc...      0
# 12     1348  Sure, I would be happy to introduce the movie ...      0
# 13     2160  Rosemary's Baby is a classic horror film that ...      0
# 14     3111  "Places in the Heart" is a drama film from 198...      1
# 15     2312  "Children of a Lesser God" is a 1986 American ...      1
# 16     2176  Rope is a classic psychological thriller film ...      0
# 17     2340  Meet Joe Black is a romantic fantasy drama fil...      1
#
#         pred                                       user_reflect  \
# 0   0.384421  Given a female user who is aged 35-44 and an a...
# 1   0.514711  Given a female user who is aged 35-44 and an a...
# 2   0.663418  Given a female user who is aged 35-44 and an a...
# 3   0.473590  A 35-44-year-old academic/educator with a dive...
# 4   0.270938  Given a female user who is aged 35-44 and an a...
# 5   0.380954  Given a female user who is aged 35-44 and an a...
# 6   0.425896  Given a female user who is aged 35-44 and an a...
# 7   0.540011  This user is a 35-44 year old academic/educato...
# 8   0.355477  Given a female user who is aged 35-44 and an a...
# 9   0.434559  Given a female user who is aged 35-44 and an a...
# 10  0.341342  Given a female user who is aged 35-44 and an a...
# 11  0.600994  Given a female user who is aged 35-44 and an a...
# 12  0.553050  Given a female user who is aged 35-44 and an a...
# 13  0.583724  This user is a 35-44 year old academic/educato...
# 14  0.445930  Given a female user who is aged 35-44 and an a...
# 15  0.490645  Given a female user who is aged 35-44 and an a...
# 16  0.503088  Given a female user who is aged 35-44 and an a...
# 17  0.330452  Given a female user who is aged 35-44 and an a...
#
#                                          item_reflect  \
# 0   A Star is Born is a 1937 American drama film t...
# 1   Ronin is a 1998 thriller movie directed by Joh...
# 2   East of Eden is a timeless classic drama film ...
# 3   Erin Brockovich is a biographical drama film t...
# 4   The Mummy is a 1999 American action-adventure ...
# 5   Superman is a 1978 superhero film directed by ...
# 6   For Love of the Game is a romantic sports dram...
# 7   "What's Love Got to Do with It?" is a 1993 bio...
# 8   Splash is a charming romantic comedy film rele...
# 9   Steel Magnolias is a 1989 American comedy-dram...
# 10  Dead Men Don't Wear Plaid is a 1982 comedy fil...
# 11  The Birds is a 1963 horror-thriller film direc...
# 12  Released in 1922, Nosferatu is a German silent...
# 13  Rosemary's Baby is a classic horror film relea...
# 14  "Places in the Heart" is a critically acclaime...
# 15  "Children of a Lesser God" is an 1986 romantic...
# 16  Rope is a classic psychological thriller film ...
# 17  Meet Joe Black is a romantic fantasy drama fil...
#
#                                          init_context
# 0   Revised User History:\nGiven a female user who...
# 1   Revised User History:\n\nGiven a female user w...
# 2   Revised User History:\nGiven a female user who...
# 3   Here are the revised user history and item des...
# 4   Revised User History:\nGiven a female user who...
# 5   Revised User History:\nGiven a female user who...
# 6   Here are the revised user history and item des...
# 7   Here are the revised user history and item des...
# 8   Revised User History:\nGiven a female user who...
# 9   Here are the revised user history and item des...
# 10  Here are the revised user history and item des...
# 11  Here is the revised user history and item desc...
# 12  Revised User History:\nGiven a female user who...
# 13  Here are the revised user history and item des...
# 14  Here are the revised user history and item des...
# 15  Revised User History:\n\nGiven a female user w...
# 16  Revised User History:\nGiven a female user who...
# 17  Here is the revised user history and item desc...

# %%
sub_df.loc[0,'user_reflect']

# %%
sub_df.loc[0,'user_hist']
# Out:
# 'Given a male user who is aged 35-44 and a tradesman/craftsman, this user\'s movie viewing history over time is listed below. Last of the Mohicans, The (1992), 4 stars; Unforgiven (1992), 5 stars; Pale Rider (1985), 5 stars; Gattaca (1997), 2 stars; Legends of the Fall (1994), 5 stars; Milk Money (1994), 3 stars; Kelly\'s Heroes (1970), 4 stars; One Flew Over the Cuckoo\'s Nest (1975), 4 stars; Star Wars: Episode V - The Empire Strikes Back (1980), 3 stars; Raiders of the Lost Ark (1981), 4 stars. Based on the user\'s movie viewing history, it seems that he enjoys action and adventure movies with strong male leads. The user has given high ratings to movies like "Unforgiven," "Pale Rider," and "Legends of the Fall," which all feature rugged, tough male protagonists. The user also enjoys classic war movies like "Kelly\'s Heroes" and "Raiders of the Lost Ark," both of which have strong male leads.\n\nHowever, the user also seems to appreciate movies with more complex themes and characters. "One Flew Over the Cuckoo\'s Nest" is a classic film that explores mental illness and institutionalization, while "Gattaca" deals with issues of genetic engineering and discrimination. These movies may appeal to the user\'s intellectual side.\n\nThe user\'s lower rating for "Star Wars: Episode V - The Empire Strikes Back" may suggest that he is not a huge fan of sci-fi or fantasy movies. However, the user may still enjoy action-driven movies like "Star Wars" as long as they have strong male leads and a compelling plot.\n\nOverall, the user seems to prefer movies with strong male leads, action and adventure, complex themes and characters, and high production quality. The user may also appreciate movies with critical acclaim or awards, as many of the movies in his viewing history have received positive reviews and recognition.'

# %%
new_user_history = sub_df_clean['user_reflect'].tolist()
new_item_description = sub_df_clean['item_reflect'].tolist()

# %%
data_l = DataLoader(new_user_history,2, shuffle=False)
new_user_vec = inference(encoding_model, tokenizer, data_l, 'bert', 'avg')
# Out:
# 100%|██████████| 9/9 [00:00<00:00, 37.81it/s]

# %%
data_l = DataLoader(new_item_description,2, shuffle=False)
new_item_vec = inference(encoding_model, tokenizer, data_l, 'bert', 'avg')
# Out:
# 100%|██████████| 9/9 [00:00<00:00, 59.03it/s]

# %%
l = []
cnt= 0
for item in train_set:
    l.append(item)
    cnt+=1
    if cnt>200:
        break
train_dataset = DictDataset(l)

# %%
train_dataset[18]['hist_aug_vec'][:10]
# Out:
# tensor([-0.4031,  0.0147,  0.1539, -0.0502,  0.4482,  0.1345,  0.3013,  0.1704,
#         -0.1854,  0.3938])

# %%
for idx, row in sub_df_clean.iterrows():
    train_idx = row['test_index']
    print(train_idx)
    train_dataset[train_idx]['hist_aug_vec'] = 0
    train_dataset[train_idx]['hist_aug_vec'] = torch.tensor(new_user_vec[idx])
    train_dataset[train_idx]['item_aug_vec'] = 0
    train_dataset[train_idx]['item_aug_vec'] = torch.tensor(new_item_vec[idx])
# Out:
# 29
# 34
# 39
# 59
# 60
# 65
# 79
# 84
# 86
# 87
# 88
# 90
# 94
# 96
# 97
# 99
# 100
# 105

# %%
train_dataset[18]['hist_aug_vec'][:10]
# Out:
# tensor([-0.4031,  0.0147,  0.1539, -0.0502,  0.4482,  0.1345,  0.3013,  0.1704,
#         -0.1854,  0.3938])

# %%
test_loader = Data.DataLoader(dataset=test_dataset, batch_size=2, shuffle=False)
short_test = ShortDataLoader(test_loader, num_batches=100)
auc, ll, loss, eval_time, labels, preds = eval(inference_model, short_test)

# %%
labels[18], preds[18]
# Out:
# (0, [0.708030104637146])

# %%
sub_df['test_index'].to_list()
# Out:
# [4,
#  18,
#  24,
#  29,
#  31,
#  34,
#  39,
#  54,
#  57,
#  59,
#  60,
#  64,
#  65,
#  69,
#  74,
#  79,
#  84,
#  85,
#  86,
#  87,
#  88,
#  90,
#  94,
#  95,
#  96,
#  97,
#  99,
#  100,
#  105,
#  107]

# %%
# prompt: take from list only the indexes from another list

def get_indexes(list1, list2):
  return [e for i, e in enumerate(list1) if i in list2]

# %%
new_labels = [v for i , v in enumerate(labels) if i in sub_df_clean['test_index'].to_list()]
new_preds = [v[0] for i , v  in enumerate(preds) if i in sub_df_clean['test_index'].to_list()]
new_labels
# Out:
# [1, 0, 0, 1, 1, 1, 1, 0, 1, 1, 1, 0, 0, 0, 1, 1, 0, 1]

# %%
new_preds
# Out:
# [0.4336511194705963,
#  0.4532131254673004,
#  0.7217369079589844,
#  0.6745705604553223,
#  0.31332603096961975,
#  0.4512385129928589,
#  0.40330809354782104,
#  0.5837703347206116,
#  0.3552521765232086,
#  0.506752073764801,
#  0.38986751437187195,
#  0.5957568287849426,
#  0.5156009793281555,
#  0.5262630581855774,
#  0.5289294719696045,
#  0.4980555474758148,
#  0.6564141511917114,
#  0.4624698758125305]

# %%
sub_df_clean['new label'] = new_labels
sub_df_clean['new pred'] = new_preds
sub_df_clean
# Out:
# <ipython-input-61-4f1ed2965461>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df_clean['new label'] = new_labels
# <ipython-input-61-4f1ed2965461>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df_clean['new pred'] = new_preds
#     test_index user_idx                                          user_hist  \
# 0           29     1034  Given a female user who is aged 35-44 and an a...
# 1           34     1034  Given a female user who is aged 35-44 and an a...
# 2           39     1034  Given a female user who is aged 35-44 and an a...
# 3           59     1034  Given a female user who is aged 35-44 and an a...
# 4           60     1034  Given a female user who is aged 35-44 and an a...
# 5           65     1034  Given a female user who is aged 35-44 and an a...
# 6           79     1034  Given a female user who is aged 35-44 and an a...
# 7           84     1034  Given a female user who is aged 35-44 and an a...
# 8           86     1034  Given a female user who is aged 35-44 and an a...
# 9           87     1034  Given a female user who is aged 35-44 and an a...
# 10          88     1034  Given a female user who is aged 35-44 and an a...
# 11          90     1034  Given a female user who is aged 35-44 and an a...
# 12          94     1034  Given a female user who is aged 35-44 and an a...
# 13          96     1034  Given a female user who is aged 35-44 and an a...
# 14          97     1034  Given a female user who is aged 35-44 and an a...
# 15          99     1034  Given a female user who is aged 35-44 and an a...
# 16         100     1034  Given a female user who is aged 35-44 and an a...
# 17         105     1034  Given a female user who is aged 35-44 and an a...
#
#    item_idx                                          item_desc  label  \
# 0      3217  "A Star is Born" is a 1937 American drama film...      1
# 1      2278  Ronin is a 1998 thriller movie directed by Joh...      0
# 2       949  East of Eden is a classic drama film released ...      0
# 3      3408  Erin Brockovich is a biographical drama film t...      1
# 4      2617  The Mummy is a 1999 American action-adventure ...      1
# 5      2640  Superman is a 1978 superhero film directed by ...      1
# 6      2861  For Love of the Game is a romantic sports dram...      1
# 7       477  What's Love Got to Do with It? is a 1993 biogr...      0
# 8      2100  Splash is a romantic comedy film released in 1...      1
# 9      3844  Steel Magnolias is a 1989 American comedy-dram...      1
# 10     2110  Dead Men Don't Wear Plaid is a 1982 comedy fil...      1
# 11     1333  The Birds is a 1963 horror-thriller film direc...      0
# 12     1348  Sure, I would be happy to introduce the movie ...      0
# 13     2160  Rosemary's Baby is a classic horror film that ...      0
# 14     3111  "Places in the Heart" is a drama film from 198...      1
# 15     2312  "Children of a Lesser God" is a 1986 American ...      1
# 16     2176  Rope is a classic psychological thriller film ...      0
# 17     2340  Meet Joe Black is a romantic fantasy drama fil...      1
#
#         pred                                       user_reflect  \
# 0   0.384421  Given a female user who is aged 35-44 and an a...
# 1   0.514711  Given a female user who is aged 35-44 and an a...
# 2   0.663418  Given a female user who is aged 35-44 and an a...
# 3   0.473590  A 35-44-year-old academic/educator with a dive...
# 4   0.270938  Given a female user who is aged 35-44 and an a...
# 5   0.380954  Given a female user who is aged 35-44 and an a...
# 6   0.425896  Given a female user who is aged 35-44 and an a...
# 7   0.540011  This user is a 35-44 year old academic/educato...
# 8   0.355477  Given a female user who is aged 35-44 and an a...
# 9   0.434559  Given a female user who is aged 35-44 and an a...
# 10  0.341342  Given a female user who is aged 35-44 and an a...
# 11  0.600994  Given a female user who is aged 35-44 and an a...
# 12  0.553050  Given a female user who is aged 35-44 and an a...
# 13  0.583724  This user is a 35-44 year old academic/educato...
# 14  0.445930  Given a female user who is aged 35-44 and an a...
# 15  0.490645  Given a female user who is aged 35-44 and an a...
# 16  0.503088  Given a female user who is aged 35-44 and an a...
# 17  0.330452  Given a female user who is aged 35-44 and an a...
#
#                                          item_reflect  \
# 0   A Star is Born is a 1937 American drama film t...
# 1   Ronin is a 1998 thriller movie directed by Joh...
# 2   East of Eden is a timeless classic drama film ...
# 3   Erin Brockovich is a biographical drama film t...
# 4   The Mummy is a 1999 American action-adventure ...
# 5   Superman is a 1978 superhero film directed by ...
# 6   For Love of the Game is a romantic sports dram...
# 7   "What's Love Got to Do with It?" is a 1993 bio...
# 8   Splash is a charming romantic comedy film rele...
# 9   Steel Magnolias is a 1989 American comedy-dram...
# 10  Dead Men Don't Wear Plaid is a 1982 comedy fil...
# 11  The Birds is a 1963 horror-thriller film direc...
# 12  Released in 1922, Nosferatu is a German silent...
# 13  Rosemary's Baby is a classic horror film relea...
# 14  "Places in the Heart" is a critically acclaime...
# 15  "Children of a Lesser God" is an 1986 romantic...
# 16  Rope is a classic psychological thriller film ...
# 17  Meet Joe Black is a romantic fantasy drama fil...
#
#                                          init_context  new label  new pred
# 0   Revised User History:\nGiven a female user who...          1  0.433651
# 1   Revised User History:\n\nGiven a female user w...          0  0.453213
# 2   Revised User History:\nGiven a female user who...          0  0.721737
# 3   Here are the revised user history and item des...          1  0.674571
# 4   Revised User History:\nGiven a female user who...          1  0.313326
# 5   Revised User History:\nGiven a female user who...          1  0.451239
# 6   Here are the revised user history and item des...          1  0.403308
# 7   Here are the revised user history and item des...          0  0.583770
# 8   Revised User History:\nGiven a female user who...          1  0.355252
# 9   Here are the revised user history and item des...          1  0.506752
# 10  Here are the revised user history and item des...          1  0.389868
# 11  Here is the revised user history and item desc...          0  0.595757
# 12  Revised User History:\nGiven a female user who...          0  0.515601
# 13  Here are the revised user history and item des...          0  0.526263
# 14  Here are the revised user history and item des...          1  0.528929
# 15  Revised User History:\n\nGiven a female user w...          1  0.498056
# 16  Revised User History:\nGiven a female user who...          0  0.656414
# 17  Here is the revised user history and item desc...          1  0.462470

# %%
y_true = sub_df_clean['label'].to_list()
y_pred = sub_df_clean['pred'].to_list()
log_loss(y_true, y_pred)
# Out:
# 0.9047640904842554

# %%
y_true = sub_df_clean['label'].to_list()
y_pred = sub_df_clean['new pred'].to_list()

log_loss(y_true, y_pred)
# Out:
# 0.8367030164913698
